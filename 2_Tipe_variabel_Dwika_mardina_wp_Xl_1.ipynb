# %% [markdown]
# <a href="https://colab.research.google.com/github/dwikapuji/KKAsmt1-/blob/main/2_Tipe_variabel_Dwika_mardina_wp_Xl_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Dwika mardina wahyuning puji
#
# kelas:Xl-1
#
# No.absen:08

# %% [markdown]
# Konsep Dasar

# %%
email_user_1 ="dwikamardinawp@gmail.com "

print(email_user_1)
# Out:
# dwikamardinawp@gmail.com

# %%
sabun_lifebouy =15000

print(sabun_lifebouy)
# Out:
# 15000

# %%
print(sabun_lifebouy*5)
# Out:
# 75000

# %% [markdown]
# peraturan penulisan variabel

# %%
#penulisan variabel hanya boleh menggunakan huruf,angka dan undercore
#Tidak boleh menggunakan spasi
nama siswa ="ika"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-763107403.py", line 3
#     nama siswa ="ika"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka

1_nama_siswa = "ika"

print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-537763442.py", line 3
#     1_nama_siswa = "ika"
#      ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case sensitive/sensitif capslock

nama_siswa_1 ="ika"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3202664534.py in <cell line: 0>()
#       2 nama_siswa_1 ="ika"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#Dilarang menggunakan kata kunci di Bahasa python
prin = "ika"
print(prin)
# Out:
# ika

# %%
end ="ika"
print (end)
# Out:
# ika

# %%
#Deskriptif
_ = "ika"
print(_)
# Out:
# ika

# %%
#Tidak boleh pakai kata kunci python
#kalau error,harus disconnect dulu
#print = "ika"

#print(print)

# %% [markdown]
# ##Assigment

# %% [markdown]
# ##single Assigment

# %%
nama_siswa_2 = "ika"
nama_siswa_3 = "alpin"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# ika
# alpin

# %% [markdown]
# ##Multiple Assignement

# %%
nama_siswa_4,nama_siswa_5 = "sada","selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# sada
# selo

# %% [markdown]
# ##Assigmen ke Banyak variabel sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #1.Single Assignment

# %%
susu = 15000
roti = 12000
telur = 24000

print("1.single Assignment ")
print(f" susu = Rp{susu:,}")
print(f" roti = Rp{ roti:,}")
print(f" telur = Rp{telur:,}\n")
# Out:
# 1.single Assignment
#  susu = Rp15,000
#  roti = Rp12,000
#  telur = Rp24,000

# %% [markdown]
# #2.Multiple Assignment

# %%
gula,minyak = 14000,20000
print("2. Multiple Assignment")
print(f" gula = Rp{gula:,}")
print(f" minyak = Rp{minyak:,}\n")
# Out:
# 2. Multiple Assignment
#  gula = Rp14,000
#  minyak = Rp20,000

# %% [markdown]
# #3.Pengisian Nilai Sama

# %%
mie_ayam = mie_soto = mie_kari = 3500
print("3. Pengisian Nilai Sama")
print(f" mie_ayam = Rp{mie_ayam:,}")
print(f" mie_soto = Rp{mie_soto:,}")
print(f" mie_kari = Rp{mie_kari:,}")
# Out:
# 3. Pengisian Nilai Sama
#  mie_ayam = Rp3,500
#  mie_soto = Rp3,500
#  mie_kari = Rp3,500

# %% [markdown]
# #4.Swap(Tukar Nilai)

# %%
print("4. Swap (sebelum Swap)")
print(f" susu = Rp{susu:,}, roti =
Rp{roti:,}") susu, roti = roti,susu
print("   (setelah swap)")
print(f" susu = Rp{susu:,}, roti =
Rp{roti:,}\n")
# Out:
#   File "/tmp/ipython-input-3675973739.py", line 2
#     print(f"susu = Rp{susu:,}, roti =
#           ^
# SyntaxError: unterminated f-string literal (detected at line 2)

# %% [markdown]
# #5.Perubahan Nilai Variabel

# %%
print("5.Perubahan Nilai Variabel ")
print(f"  telur ( sebelum) = Rp{telur:,}")
telur-= 2000 # harga telur turun Rp2.000
print(f"  telur (sesudah) = Rp{telur:,}(turun Rp2.000)")
print(f"  minyak (sebelum) = Rp{minyak -3000:,}")
minyak += 3000 # harga minyak naik Rp3.000
print(f"  minyak (sesudah) = Rp{minyak:,} (naik Rp3.000)\n")
# Out:
# 5.Perubahan Nilai Variabel
#   telur ( sebelum) = Rp24,000
#   telur (sesudah) = Rp22,000(turun Rp2.000)
#   minyak (sebelum) = Rp17,000
#   minyak (sesudah) = Rp23,000 (naik Rp3.000)

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Latihan soal

# %%
#satu kardus berisi 24  botol minuman
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# Tipe variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "ika"
type(nama)
# Out:
# str

# %%
remidi = False
type(remidi)
# Out:
# bool

# %%
remidi = True
type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5
type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang*lebar
print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1308584410.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
type(luas)
# Out:
# int

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi : "))
lebar_2 = int(input("Masukkan lebar persegi :"))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi : 4
# Masukkan lebar persegi :10
# Luas persegi panjang adalah 40 cm^2

# %% [markdown]
# Latihan soal

# %%
panjang_1 = int(input("Masukkan panjang: "))
lebar_1 = int(input("Masukkan lebar: "))
tinggi_1 = int(input("Masukkan tinggi: "))


volume_1 = panjang_1*lebar_1*tinggi_1
print(f"volume balok tersebut adalah {volume_1} cm^3")
# Out:
# Masukkan panjang: 10
# Masukkan lebar: 5
# Masukkan tinggi: 4
# volume balok tersebut adalah 200 cm^3

# %% [markdown]
# #konversi Tipe Data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e ="false"
print(e)
type(e)
# Out:
# false
# str

# %% [markdown]
# #operator perbandingan

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print (8==8)
# Out:
# True

# %%
print(8==5)
# Out:
# False

# %%
print(1!=1)
# Out:
# False

# %%
a=10
b=20
c=30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80


print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #operator logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min =125
tinggi_min= 165

print(125 >=iq_min and 170>= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa= 170

print(iq_afa  >= iq_afa and tinggi_afa >= tinggi_afa)
# Out:
# True

# %% [markdown]
# #latihan soal

# %%
tinggi_min =165
BB_min = 50
umur_min = 25

tinggi_someone = 170
BB_someone = 55
umur_someone = 23


print(tinggi_someone >= tinggi_min and BB_someone >=  BB_min and umur_someone <= umur_min)
# Out:
# True
